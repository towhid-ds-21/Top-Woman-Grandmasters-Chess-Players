# %% [markdown]
# <h1>Top Woman Grandmasters Chess Players</h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings as ws
ws.filterwarnings ("ignore")

# %%
df = pd.read_csv("top_women_chess_players_aug_2020.csv")

# %%
df.head()
# Out:
#    Fide id                     Name Federation Gender  Year_of_birth Title  \
# 0   700070            Polgar, Judit        HUN      F         1976.0    GM
# 1  8602980               Hou, Yifan        CHN      F         1994.0    GM
# 2  5008123            Koneru, Humpy        IND      F         1987.0    GM
# 3  4147103  Goryachkina, Aleksandra        RUS      F         1998.0    GM
# 4   700088            Polgar, Susan        HUN      F         1969.0    GM
#
#    Standard_Rating  Rapid_rating  Blitz_rating Inactive_flag
# 0             2675        2646.0        2736.0            wi
# 1             2658        2621.0        2601.0           NaN
# 2             2586        2483.0        2483.0           NaN
# 3             2582        2502.0        2441.0           NaN
# 4             2577           NaN           NaN            wi

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8553 entries, 0 to 8552
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Fide id          8553 non-null   int64
#  1   Name             8553 non-null   object
#  2   Federation       8553 non-null   object
#  3   Gender           8553 non-null   object
#  4   Year_of_birth    8261 non-null   float64
#  5   Title            3118 non-null   object
#  6   Standard_Rating  8553 non-null   int64
#  7   Rapid_rating     3608 non-null   float64
#  8   Blitz_rating     3472 non-null   float64
#  9   Inactive_flag    5852 non-null   object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 668.3+ KB

# %%
top_ten_players = df[:10]
top_ten_players
# Out:
#     Fide id                     Name Federation Gender  Year_of_birth Title  \
# 0    700070            Polgar, Judit        HUN      F         1976.0    GM
# 1   8602980               Hou, Yifan        CHN      F         1994.0    GM
# 2   5008123            Koneru, Humpy        IND      F         1987.0    GM
# 3   4147103  Goryachkina, Aleksandra        RUS      F         1998.0    GM
# 4    700088            Polgar, Susan        HUN      F         1969.0    GM
# 5   8600147                 Xie, Jun        CHN      F         1970.0    GM
# 6   8603006               Ju, Wenjun        CHN      F         1991.0    GM
# 7  14109336          Lagno, Kateryna        RUS      F         1989.0    GM
# 8  14114550         Muzychuk, Mariya        UKR      F         1992.0    GM
# 9  12801259       Cmilyte, Viktorija        LTU      F         1983.0    GM
#
#    Standard_Rating  Rapid_rating  Blitz_rating Inactive_flag
# 0             2675        2646.0        2736.0            wi
# ...

# %%
gms = df[df.Title=='GM'].reset_index()
gms
# Out:
#     index   Fide id                      Name Federation Gender  \
# 0       0    700070             Polgar, Judit        HUN      F
# 1       1   8602980                Hou, Yifan        CHN      F
# 2       2   5008123             Koneru, Humpy        IND      F
# 3       3   4147103   Goryachkina, Aleksandra        RUS      F
# 4       4    700088             Polgar, Susan        HUN      F
# 5       5   8600147                  Xie, Jun        CHN      F
# 6       6   8603006                Ju, Wenjun        CHN      F
# 7       7  14109336           Lagno, Kateryna        RUS      F
# 8       8  14114550          Muzychuk, Mariya        UKR      F
# 9       9  12801259        Cmilyte, Viktorija        LTU      F
# 10     10  14111330            Muzychuk, Anna        UKR      F
# 11     11  13601903           Dzagnidze, Nana        GEO      F
# 12     12   5015197        Harika, Dronavalli        IND      F
# 13     13   8603642              Tan, Zhongyi        CHN      F
# ...

# %%
print("There are total {} female chess Grandmasters (GMs) in world currently.".format(len(gms)))
# Out:
# There are total 37 female chess Grandmasters (GMs) in world currently.

# %% [markdown]
# That's it! The result is 37 female chess Gransmasters players in the world!
